# %%
import pandas as pd
s=pd.Series([1,2,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# dtype: int64

# %%
l=[1,2,3,4]
ind=['i','ii','iii','iv']
s1=pd.Series(l,index=ind,name='values')
print(s1)
print(s1['i'])
# Out:
# i      1
# ii     2
# iii    3
# iv     4
# Name: values, dtype: int64
# 1

# %%
df=pd.DataFrame({'name':['A','B','C','D'],'EID':[121,122,123,124],'Age':[22,21,20,24]})
print(df)
# Out:
#   name  EID  Age
# 0    A  121   22
# 1    B  122   21
# 2    C  123   20
# 3    D  124   24

# %%
print(df['Age'])
# Out:
# 0    22
# 1    21
# 2    20
# 3    24
# Name: Age, dtype: int64

# %%
print(df['name'][2])
# Out:
# C

# %%
df['name'][0]='Bharath'
print(df)
# Out:
#       name  EID  Age
# 0  Bharath  121   22
# 1        B  122   21
# 2        C  123   20
# 3        D  124   24
# C:\Users\valli\AppData\Local\Temp\ipykernel_22984\2626113287.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['joc']=['sde','da','ds','pfs']

# %%
print(df)
# Out:
#       name  EID  Age  joc
# 0  Bharath  121   22  sde
# 1        B  122   21   da
# 2        C  123   20   ds
# 3        D  124   24  pfs

# %%
data_frame=pd.read_csv('practice_dataset.csv')

# %%
print(data_frame.head())
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
print(data_frame.head(10))
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7       1                           Andrews, Mr. Thomas Jr    male  39.0000
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9       1                          Artagaveytia, Mr. Ramon    male  71.0000
#
#    sibsp  parch    ticket      fare    cabin embarked  survived
# 0      0      0     24160  211.3375       B5        S         1
# ...

# %%
print(data_frame.tail())
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived
# 1304  14.4542   NaN        C         0
# 1305  14.4542   NaN        C         0
# 1306   7.2250   NaN        C         0
# 1307   7.2250   NaN        C         0
# 1308   7.8750   NaN        S         0

# %%
print(data_frame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB
# None

# %%
print(data_frame.describe())
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print(data_frame.shape)
# Out:
# (1309, 11)

# %%
print(data_frame.columns)
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
print(data_frame['name'].unique())
# Out:
# ['Allen, Miss. Elisabeth Walton' 'Allison, Master. Hudson Trevor'
#  'Allison, Miss. Helen Loraine' ... 'Zakarian, Mr. Mapriededer'
#  'Zakarian, Mr. Ortin' 'Zimmerman, Mr. Leo']

# %%
print(data_frame['cabin'].value_counts())
# Out:
# cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F4                 4
# F33                4
#                   ..
# C132               1
# E60                1
# B52 B54 B56        1
# C49                1
# F38                1
# Name: count, Length: 186, dtype: int64

# %%
print(data_frame['name'].sort_values(ascending=True))
# Out:
# 600                               Abbing, Mr. Anthony
# 601                     Abbott, Master. Eugene Joseph
# 602                       Abbott, Mr. Rossmore Edward
# 603                  Abbott, Mrs. Stanton (Rosa Hunt)
# 604                       Abelseth, Miss. Karen Marie
#                             ...
# 392     del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 1262              van Billiard, Master. James William
# 1263                van Billiard, Master. Walter John
# 1264                  van Billiard, Mr. Austin Blyler
# 1268                      van Melkebeke, Mr. Philemon
# Name: name, Length: 1309, dtype: object

# %%
df.to_csv('sample.csv')
# Out:
# None

# %%
df.to_html('sample.html')

# %%
print(df['name'][0::1])
# Out:
# 0    Bharath
# 1          B
# 2          C
# 3          D
# Name: name, dtype: object

# %%
print(df[0:2:1])
# Out:
#       name  EID  Age  joc
# 0  Bharath  121   22  sde
# 1        B  122   21   da

# %%
print(df)
# Out:
#       name  EID  Age  joc
# 0  Bharath  121   22  sde
# 1        B  122   21   da
# 2        C  123   20   ds
# 3        D  124   24  pfs

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(df.loc[0:2,['name','age']])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...
